# %%
import pandas as pd 

airports = pd.read_csv('airportCodesTypeFiltered.csv')

airports.tail(30)

#values_to_drop = ['NaN']
#df_filtered = airports[~airports['iata_code'].isin(values_to_drop)]

#df_filtered.head()

airports.dropna(subset=['iata_code'], inplace=True)

airports.head()

#check to see if filtering the types removes the duplicate iata codes
#need to remove NaN
#make a list of all the vlaues in iata_codes, before adding check if already there. if already that code is already
#there then break from loop and print "Dupes exist" whil printing the dupes
# Out:
#      Unnamed: 0 ident           type                     name  elevation_ft  \
# 121         222   03N  small_airport           Utirik Airport           4.0
# 249         440  07FA  small_airport  Ocean Reef Club Airport           8.0
# 345         597   0AK  small_airport    Pilot Station Airport         305.0
# 385         676  0CO2  small_airport    Crested Butte Airpark        8980.0
# 623        1093  0TE7  small_airport        LBJ Ranch Airport        1515.0
#
#     continent iso_country iso_region   municipality gps_code iata_code  \
# 121        OC          MH     MH-UTI  Utirik Island     K03N       UTK
# 249       NaN          US      US-FL      Key Largo     07FA       OCA
# 345       NaN          US      US-AK  Pilot Station      NaN       PQS
# 385       NaN          US      US-CO  Crested Butte     0CO2       CSE
# 623       NaN          US      US-TX   Johnson City     0TE7       JCY
#
#     local_code                             coordinates
# ...

# %%
# Check for duplicate entries in the 'Iata_codes' column
duplicates = airports['iata_code'].duplicated()

# The 'duplicated' method returns a boolean Series where True indicates a duplicate entry

# If you want to see the rows with duplicate entries, you can use boolean indexing
duplicate_rows = airports[duplicates]

# If you just want to count the number of duplicates, you can use the sum() method
num_duplicates = duplicates.sum()

# Print or use the results as needed
print("Number of duplicate entries:", num_duplicates)
print("Rows with duplicate entries:")
print(duplicate_rows)
# Out:
# Number of duplicate entries: 96
# Rows with duplicate entries:
#        Unnamed: 0   ident            type  \
# 13322       21533    FNBL   small_airport
# 18701       28343  KE-MRE   small_airport
# 19767       29469     KMM   small_airport
# 26543       39494    OPDD   small_airport
# 27027       40091     PCO   small_airport
# ...           ...     ...             ...
# 37346       54337    WILP   small_airport
# 37498       54533    WPMN   small_airport
# 37508       54543    WRKR   small_airport
# 38922       56212     YNT   large_airport
# 39830       57285    ZSYA  medium_airport
#
#                                        name  elevation_ft continent  \
# 13322                       Lumbala Airport        3700.0        AF
# 18701                   Mara Lodges Airport        5706.0        AF
# 19767                        Kimaam Airport          26.0        AS
# 26543                          Dadu Airport         121.0        AS
# ...
